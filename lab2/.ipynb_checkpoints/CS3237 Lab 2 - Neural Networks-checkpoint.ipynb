# %% [markdown]
# # CS3237 Lab 2 - Neural Networks
#
# Please fill in your student number and name below. Each student is to make one submission.
#
# | Student Number | Name                 |
# |:--------------:|:--------------------:|
# | A0184893L      | Ng Wei Jie, Brandon       |
#
# **Submission:**
#
# Please upload to the respective LumiNUS folders for your group by Friday _11 September 2359 hours_ for the Tuesday 2 pm lab group, and Monday 15 September 2359 hours for the Friday 12 pm lab group.
#
#
# ## 1. Introduction
#
# The objectives of this lab are:
#
#     1. To familiarize you with how to create dense neural networks using Keras.
#     2. To familiarize you with how to encode input and output vectors for neural networks.
#     3. To give you some insight into how hyperparameters like learning rate and momentum affect training.
#
# To save time we will train each experiment only for 50 epochs. This will lead to less than optimal results but is enough for you to make observations.
#
# **HINT: YOU CAN HIT SHIFT-ENTER TO RUN EACH CELL. NOTE THAT IF A CELL IS DEPENDENT ON A PREVIOUS CELL, YOU WILL NEED TO RUN THE PREVIOUS CELL(S) FIRST **
#
#
# ## 2. The Irises Dataset
#
# We will now work again on the Irises Dataset, which we used in Lab 1, for classifying iris flowers into one of three possible types. As before we will consider four factors:
#
#     1. Sepal length in cm
#     2. Sepal width in cm
#     3. Petal length in cm
#     4. Petal width in cm
#
# In this dataset there are 150 sample points. The code below loads the dataset and prints the first 10 rows so we have an idea of what it looks like.

# %%
from sklearn.datasets import load_iris
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

iris = load_iris()

# print("First 10 rows of data:")
# print(iris.data[:10])

# %% [markdown]
# ### 2.2 Scaling the Data
#
# We make use of the MinMaxScaler to scale the inputs to between 0 and 1.  The code below does this and prints the first 10 rows again, to show us the difference.
#
# In the next section we will investigate what happens if we use unscaled data.

# %%
scaler = MinMaxScaler()
scaler.fit(iris.data)
X = scaler.transform(iris.data)

# print("First 10 rows of SCALED data.")
# print(X[:10])

# %% [markdown]
# ### 2.3 Encoding the Targets
#
# In Lab 1 we saw that the target values (type of iris flower) is a vector from 0 to 2. We can see the 150 labels below:

# %%
# print(iris.target)

# %% [markdown]
# We can use this to train the neural network, but we will use "one-hot" encoding, where we have a vector of _n_ integers consisting of 0's and 1's.  The table below shows how one-hot encoding works:
#
# |   Value    |    One-Hot Encoding    |
# |:----------:|:----------------------:|
# | 0 | \[1 0 0\] |
# | 1 | \[0 1 0\] |
# | 2 | \[0 0 1\] |
#
# Keras provides the to_categorical function to create one-hot vectors:

# %%
from keras.utils import to_categorical

Y = to_categorical(y = iris.target, num_classes = 3)
# print(Y)

# %% [markdown]
# Now let's split the data into training and testing data:

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, 
                                                    random_state = 1)

# %% [markdown]
# ### 2.4 Building our Neural Network
#
# Let's now begin building a simple neural network with a single hidden layer, using the Stochastic Gradient Descent (SGD) optimizer, ReLu transfer functions for the hidden layer and softmax for the output layer.
#
# The code to do this is shown below:

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

# Create the neural network
nn = Sequential()
nn.add(Dense(100, input_shape = (4, ), activation = 'relu'))
nn.add(Dense(3, activation = 'softmax'))

# Create our optimizer
sgd = SGD(lr = 0.1)

# 'Compile' the network to associate it with a loss function,
# an optimizer, and what metrics we want to track
nn.compile(loss='categorical_crossentropy', optimizer=sgd, 
          metrics = 'accuracy')

# %% [markdown]
# ### 2.5 Training the Neural Network
#
# As is usually the case, we can call the "fit" method to train the neural network for 50 epochs. We will shuffle the training data between epochs, and provide validation data.

# %%
history = nn.fit(X_train, Y_train, shuffle = True, epochs = 50, 
      validation_data = (X_test, Y_test), verbose=False)

# %%
from matplotlib import pyplot as plt

print(history.history.keys())
print(history.history['accuracy'][-1])
print(history.history['val_accuracy'][-1])
#  "Accuracy"
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# 0.9083333611488342
# 0.9666666388511658

# %%
def evaluate_model_lr(lr):
    # Create the neural network
    model = Sequential()
    model.add(Dense(100, input_shape = (4, ), activation = 'relu'))
    model.add(Dense(3, activation = 'softmax'))

    # Create our optimizer
    sgd = SGD(lr = lr)

    # 'Compile' the network to associate it with a loss function,
    # an optimizer, and what metrics we want to track
    model.compile(loss='categorical_crossentropy', optimizer=sgd, 
              metrics = 'accuracy')
    history = model.fit(X_train, Y_train, shuffle = True, epochs = 50, 
      validation_data = (X_test, Y_test), verbose=False)

    
    #  "Accuracy"
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()

    # "Loss"
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()

    print("Learning Rate: ", lr)
    print("Training Accuracy: ", history.history['accuracy'][-1])
    print("Validation Accuracy: ", history.history['val_accuracy'][-1])
    
lrs = [0.01, 0.1, 1.0, 10.0, 100, 1000, 10000, 100000]
for lr in lrs:
    evaluate_model_lr(lr=lr)
# Out:
# Learning Rate:  0.01
# Training Accuracy:  0.6916666626930237
# Validation Accuracy:  0.5666666626930237
# Learning Rate:  0.1
# Training Accuracy:  0.9583333134651184
# Validation Accuracy:  0.9333333373069763
# Learning Rate:  1.0
# Training Accuracy:  0.9166666865348816
# Validation Accuracy:  0.9666666388511658
# Learning Rate:  10.0
# Training Accuracy:  0.3166666626930237
# Validation Accuracy:  0.20000000298023224
# Learning Rate:  100
# Training Accuracy:  0.3083333373069763
# Validation Accuracy:  0.36666667461395264
# Learning Rate:  1000
# Training Accuracy:  0.3333333432674408
# Validation Accuracy:  0.4333333373069763
# Learning Rate:  10000
# Training Accuracy:  0.3083333373069763
# Validation Accuracy:  0.36666667461395264
# Learning Rate:  100000
# Training Accuracy:  0.6833333373069763
# Validation Accuracy:  0.5666666626930237

# %%
def evaluate_model_m(m):
    # Create the neural network
    model = Sequential()
    model.add(Dense(100, input_shape = (4, ), activation = 'relu'))
    model.add(Dense(3, activation = 'softmax'))

    # Create our optimizer
    sgd = SGD(lr = 0.1, momentum=m)

    # 'Compile' the network to associate it with a loss function,
    # an optimizer, and what metrics we want to track
    model.compile(loss='categorical_crossentropy', optimizer=sgd, 
              metrics = 'accuracy')
    history = model.fit(X_train, Y_train, shuffle = True, epochs = 50, 
      validation_data = (X_test, Y_test), verbose=False)

    
    #  "Accuracy"
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()

    # "Loss"
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()

    print("Momentum: ", m)
    print("Training Accuracy: ", history.history['accuracy'][-1])
    print("Validation Accuracy: ", history.history['val_accuracy'][-1])
    
ms = [0.001, 0.01, 0.1, 1.0]
for m in ms:
    evaluate_model_m(m=m)
# Out:
# Momentum:  0.001
# Training Accuracy:  0.9416666626930237
# Validation Accuracy:  0.9666666388511658
# Momentum:  0.01
# Training Accuracy:  0.9416666626930237
# Validation Accuracy:  0.9666666388511658
# Momentum:  0.1
# Training Accuracy:  0.9583333134651184
# Validation Accuracy:  0.9666666388511658
# Momentum:  1.0
# Training Accuracy:  0.8833333253860474
# Validation Accuracy:  0.9333333373069763

# %% [markdown]
# ---
# #### Question 1
#
# Run the code above. Do you see evidence of underfitting? Overfitting? Justify your answers. ***(4 MARKS)***
#
# **Answer: The training and validation loss are still decreasing slightly. Therefore, there is evidence of underfitting as the model can still be trained. The gap between training and validation loss is small, and the validation loss is not increasing while the training loss is decreasing. Therefore, there is no evidence of overfitting.**
#
# _(For TA) Marks awarded: ____ / 4_
#
# ---
#
# #### Question 2a
#
# Consult the documentation for the SGD optimizer [here](https://keras.io/api/optimizers/sgd/). What does the lr parameter do? ***(1 MARK)***
#
# **Answer: The paramter lr is the learning rate, a hyperparameter that controls how much to change the model in response to the estimated error each time the model weights are updated. The weights of the model change more for larger values of lr.**
#
# #### Question 2b
#
# The documentation states that the momentum parameter "accelerates gradient descent in the relevant direction and dampens oscillations". Using Google or other means, illustrate what this means. ***(2 MARKS)***
#
# **Answer: Momentum "accelerates gradient descent in the relevant direction" means that it speeds up the learning (increasing the learning rate) when the error cost gradient is heading in the same direction for a long time and avoids local minima by 'rolling over' small bumps. Momentum "dampens oscillations" means than it takes the moving average to smoothen the progression of the learning algorithm.**
#
# _(For TA) Marks awarded: ____ / 3_
#
# ----
#
# #### Question 3a
#
# We will now play with the lr parameter. Adjust the lr parameter to the following values and record the final training and validation accuracies in the respective columns. Also observe the sequence of accuracies over the training period, and place your observation in the "remarks" column, e.g. "Progresses steadily", "some oscillation" etc. ***(3 MARKS)***
#
# **Answer: Fill the table below **
#
# |  lr    | Training Acc. | Validation Acc. |      Remarks      |
# |:------:|---------------|-----------------|-------------------|
# |0.01    |0.6916               |0.5666                 |Underfit at plateau                     |
# |0.1     |0.9583               |0.9333                 |Progressing steadily                    |
# |1.0     |0.9166               |0.9666                 |Some oscillations                       |
# |10.0    |0.3166               |0.2000                 |Big oscillations                        |
# |100     |0.3083               |0.3666                 |Big oscillations                        |
# |1000    |0.3333               |0.4333                 |Big oscillations                        |
# |10000   |0.3083               |0.3666                 |Big oscillations                        |
# | 100000 |0.6833               |0.5666                 |Big oscillations                        |
#
#
# #### Question 3b
#
# Based on your observations above, comment on the effect of small and very large learning rates on the learning. ***(2 MARKS)***
#
# **Answer: The model converges slower for a small learning rate. The model is underfitted when learning rate is 0.01. The model becomes more unstable for larger learning rates. The training and validation accuracy overshoot and show larger oscillations for larger learning rates 10 and higher.**
#
# _(For TA) Marks awarded: ____ / 5_
#
# ### 2.5 Using Momentum
#
# We will now experiment with the momentum term. To do this:
#
#     1. Change the learning rate to 0.1.
#     2. Set the momentum to 0.1. Note: Do not use the Nesterov parameter - Leave it as False.
#
# Run your neural network.
#
# ---
#
# #### Question 4a
#
# Keeping the learning rate at 0.1, complete the table below using the momentum values shown. Again record any observations in the "Remarks" column. ***(3 MARKS)***
#
# **Answer: Fill the table below**
#
# | momentum | Training Acc. | Validation Acc. |      Remarks      |
# |:--------:|---------------|-----------------|-------------------|
# |0.001     |0.9416               |0.9666                 |Converge slowest, smoothest oscillations       |
# |0.01      |0.9416               |0.9666                 |Converge slower, smoother oscillations         |
# |0.1       |0.9583               |0.9666                 |Converge faster, smooth oscillations           |
# |1.0       |0.8833               |0.9333                 |Converge fastest, huge oscillations for loss   |
#
# #### Question 4b
#
# Based on your observations above, does the momentum term help in learning? ***(2 MARKS)***
#
# **Answer: For momentum 0.001 and 0.01, the model converges slower and the oscillations are relatively smoother. For momentum 1.0, the model converges fastest but the oscillations for accuracy and validation loss is large. The momentum helps to accelerate the learning rate and reduces the fluctuations as the model converges. Beyond a point, the momemtum does not help as the fluctuations are unstable.**
#
# _(For TA) Marks awarded: ____ / 5_
#
# ---
#
# ### 2.6 Using Raw Unscaled Data
#
# We begin by using unscaled X and Y data. The code below will create 120 training samples and 30 testing samples (20% of the total of 150 samples):

# %%
X_unscaled = iris.data
Y_raw = iris.target
X_utrain, X_utest, Y_utrain, Y_utest = train_test_split(X_unscaled, Y,
                                                        test_size = 0.2,
                                                        random_state = 1)

# %% [markdown]
# ---
#
# #### Question 5
#
# Create a new neural network called "nn2" below using a single hidden layer of 100 neurons. Train using the data in X_utrain, X_utest and validate with Y_utrain and Y_utest. Again use the SGD optimizer with a learning rate of 0.1 and no momentum, and train for 50 epochs. ***(3 marks)***

# %%
"""
Enter your code for Question 5 below. To TA: 3 marks for code.
"""
# Create the neural network
nn2 = Sequential()
nn2.add(Dense(100, input_shape = (4, ), activation = 'relu'))
nn2.add(Dense(3, activation = 'softmax'))

# Create our optimizer
sgd = SGD(lr = 0.1)

# 'Compile' the network to associate it with a loss function,
# an optimizer, and what metrics we want to track
nn2.compile(loss='categorical_crossentropy', optimizer=sgd, 
          metrics = 'accuracy')

# %%
history = nn2.fit(X_utrain, Y_utrain, shuffle = True, epochs = 50, 
      validation_data = (X_utest, Y_utest), verbose=False)

# %%
print(history.history.keys())
print(history.history['accuracy'][-1])
print(history.history['val_accuracy'][-1])
#  "Accuracy"
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# 0.875
# 0.800000011920929

# %% [markdown]
# **(Question 5 continues)**
#
# Observe the training and validation error. Does not scaling the input affect the training? Why do you think this is so? What is the advantage of scaling? ***(5 MARKS)***
#
# **Answer: Scaling has affect on the model training. For the same hyperparamters, the training and validation accuracy for the unscaled training data have huge oscillations. An unscaled training data means that a feature may have a larger range of values than other features and more significant numbers play a more decisive role in training the data. The model ended up learning the data poorly because it places emphasis on the larger numbers. It also converges slower. Scaling allows the model to place equal importance on the scaled features that are represented in numbers when it learns the data. Therefore, the model is able to learn the data better without placing emphasis on one feature over the other due to the range, and the model converges faster.**
#
# _(For TA) Marks awarded: ____ / 8_
#
# ---

# %% [markdown]
# ## 3 Conclusion
#
# In this lab we saw how to create a simple Dense neural network to complete the relatively simple task of learning how to classify irises according to their sepal and petal characteristics.
#
#
# ---
#
# ***FOR TA ONLY***
#
# | Question |  Marks  |
# |:--------:|:-------:|
# |1         |     /4  |
# |2         |     /3  |
# |3         |     /5  |
# |4         |     /5  |
# |5         |     /8  |
# |Total:    |     /25 |
